# %% [markdown]
# PANDAS BASICS
# 1. PYTHON LIBRARY
# 2. They are used to analyze the large dataset to get underlying answers and answer the questions related to it
# 3. Excel cannot handle large amount of data so we use PANDAS

# %%
# importing pandas 
import pandas as pd

# %%
# Reading the dataset
df = pd.read_csv("C:\\Users\\harip\\Desktop\\refrence\\data_science\\dataset\\nyc_weather.csv")

# %% [markdown]
# HEAD & TAIL FUNCTION

# %%
df.head()
# they give starting 5 rows of the dataframe
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.tail()
# they give ending 5 rows of the dataframe
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %% [markdown]
# NOTE : They process of cleaning messy data is called Data Munging

# %% [markdown]
# BASICS FUNCTION'S IN PANDAS

# %% [markdown]
# * Check & Fill NA values

# %%
# To check na values
df.isna()

# to check the total count of na values in each col
df.isna().sum()

# NOTE filling the na values 
df.fillna(1, inplace=True)

# NOTE we check again
df.isna().sum()
# Out:
# EST                     0
# Temperature             0
# DewPoint                0
# Humidity                0
# Sea Level PressureIn    0
# VisibilityMiles         0
# WindSpeedMPH            0
# PrecipitationIn         0
# CloudCover              0
# Events                  0
# WindDirDegrees          0
# dtype: int64
