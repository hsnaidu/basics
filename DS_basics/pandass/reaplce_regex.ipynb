# %%
import pandas as pd

# %% [markdown]
# REPLACING THE VALUES USING REGEX

# %%
df = pd.read_excel("C:\\Users\\harip\\Desktop\\refrence\\data_science\\dataset\\crop.xlsx")
df.head()
# Out:
#    Sl.No                  Sample No                           Farmer Name  \
# 0      1  KA622935/2017-18/22220754                       S.Krishnamurthy
# 1      2  KA622935/2018-19/25750616                        S.NAGABHUSHANA
# 2      3  KA622935/2017-18/24870613         G RAMAKRISHNAPPA S/O GURRAPPA
# 3      4  KA622935/2017-18/24870613  LAKSHMIDEVAMMA W/O VENKATACHALAPATHI
# 4      5  KA622935/2017-18/24870613  LAKSHMIDEVAMMA W/O VENKATACHALAPATHI
#
#    Land Area  Survey No  Longitude  Lattitude            pH            EC  \
# 0       1.50          1  78.571944  13.167778  7.20000 MAl   0.91000 N
# 1       0.16          3  78.292426  13.109093  6.60000 SlAc  0.66000 N
# 2       0.20          5  78.557222  13.194722  7.60000 MAl   0.54000 N
# 3       0.50          5  78.557222  13.194722  7.60000 MAl   0.54000 N
# 4       0.80          5  78.557222  13.194722  7.60000 MAl   0.54000 N
#
#            OC  ...         Cu          Mn          B Fertility Index  \
# ...

# %% [markdown]
# WE REPLACE USING THE REGEX METHOD

# %%
df.replace('[a-zA-Z]',' ',regex=True) # but the other values containing the alphabet have also been swoshed!!!
# Out:
#      Sl.No                  Sample No                           Farmer Name  \
# 0        1    622935/2017-18/22220754                        .
# 1        2    622935/2018-19/25750616                         .
# 2        3    622935/2017-18/24870613                           /
# 3        4    622935/2017-18/24870613                  /
# 4        5    622935/2017-18/24870613                  /
# ..     ...                        ...                                   ...
# 753    754    622935/2017-18/22252367
# 754    755    622935/2018-19/25744704                           /
# 755    756    622935/2017-18/22220443                          /
# 756    757    622935/2017-18/22920950               . .        /
# 757    758    622935/2017-18/22920950                      /
#
#      Land Area  Survey No  Longitude  Lattitude            pH            EC  \
# 0         1.50          1  78.571944  13.167778  7.20000       0.91000
# ...

# %%
df.head()
# Out:
#    Sl.No                  Sample No                           Farmer Name  \
# 0      1  KA622935/2017-18/22220754                       S.Krishnamurthy
# 1      2  KA622935/2018-19/25750616                        S.NAGABHUSHANA
# 2      3  KA622935/2017-18/24870613         G RAMAKRISHNAPPA S/O GURRAPPA
# 3      4  KA622935/2017-18/24870613  LAKSHMIDEVAMMA W/O VENKATACHALAPATHI
# 4      5  KA622935/2017-18/24870613  LAKSHMIDEVAMMA W/O VENKATACHALAPATHI
#
#    Land Area  Survey No  Longitude  Lattitude            pH            EC  \
# 0       1.50          1  78.571944  13.167778  7.20000 MAl   0.91000 N
# 1       0.16          3  78.292426  13.109093  6.60000 SlAc  0.66000 N
# 2       0.20          5  78.557222  13.194722  7.60000 MAl   0.54000 N
# 3       0.50          5  78.557222  13.194722  7.60000 MAl   0.54000 N
# 4       0.80          5  78.557222  13.194722  7.60000 MAl   0.54000 N
#
#            OC  ...         Cu          Mn          B Fertility Index  \
# ...

# %% [markdown]
# SO, HERE WE USE DICT

# %%
df.replace({
    'pH' : '[a-zA-Z]',
    'EC' : '[a-zA-Z]',
    'OC' : '[a-zA-Z]'
} , " " , regex = True , inplace= True)
df.head()
# Out:
#    Sl.No                  Sample No                           Farmer Name  \
# 0      1  KA622935/2017-18/22220754                       S.Krishnamurthy
# 1      2  KA622935/2018-19/25750616                        S.NAGABHUSHANA
# 2      3  KA622935/2017-18/24870613         G RAMAKRISHNAPPA S/O GURRAPPA
# 3      4  KA622935/2017-18/24870613  LAKSHMIDEVAMMA W/O VENKATACHALAPATHI
# 4      5  KA622935/2017-18/24870613  LAKSHMIDEVAMMA W/O VENKATACHALAPATHI
#
#    Land Area  Survey No  Longitude  Lattitude            pH            EC  \
# 0       1.50          1  78.571944  13.167778  7.20000       0.91000
# 1       0.16          3  78.292426  13.109093  6.60000       0.66000
# 2       0.20          5  78.557222  13.194722  7.60000       0.54000
# 3       0.50          5  78.557222  13.194722  7.60000       0.54000
# 4       0.80          5  78.557222  13.194722  7.60000       0.54000
#
#            OC  ...         Cu          Mn          B Fertility Index  \
# ...
